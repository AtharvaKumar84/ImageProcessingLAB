# %%
pip install opencv python
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement opencv (from versions: none)
# ERROR: No matching distribution found for opencv

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imshow, imread
from skimage.color import rgb2hsv
from skimage.color import rgb2gray
from skimage import img_as_uint

# %%
array_1 = np.array([[255, 0],
[0, 255]])
imshow(array_1, cmap ='gray');
plt.show()
# Out:
# C:\Users\ML\anaconda3\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
array_2 = np.array([[255, 0, 255],
[0, 255, 0],
[255, 0, 255]])
imshow(array_2, cmap = 'gray');
plt.show()

# %%
array_spectrum = np.array([np.arange(0,255,17),
np.arange(255,0,-17),
np.arange(0,255,17),
np.arange(255,0,-17)]) fig, ax =
plt.subplots(1, 2,
figsize=(12,4))ax[0].imshow(array_spectrum, cmap
= 'gray')
plt.show()
# Out:
#   Cell In[21], line 4
#     np.arange(255,0,-17)]) fig, ax =
#                            ^
# SyntaxError: invalid syntax

# %%
cat=imread('cat.jpg')
imshow(cat)

# %%
array_spectrum = np.array([
    np.arange(0, 255, 17),
    np.arange(255, 0, -17),
    np.arange(0, 255, 17),
    np.arange(255, 0, -17)
])

fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].imshow(array_spectrum, cmap='gray')
ax[0].set_title('Arange Generation')
ax[1].imshow(array_spectrum.T, cmap='gray')
ax[1].set_title('Transpose Generation')
# Out:
# Text(0.5, 1.0, 'Transpose Generation')

# %%
array_colors = np.array([[[255, 0, 0],
                          [0, 255, 0],
                          [0, 0, 255]]])
imshow(array_colors)
# Out:
# C:\Users\ML\anaconda3\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
fig, ax = plt.subplots(1, 3, figsize=(6, 4), sharey=True)

ax[0].imshow(cat[:, 0:1000])
ax[0].set_title('First Split')

ax[1].imshow(cat[:, 1000:2000])
ax[1].set_title('Second Split')

ax[2].imshow(cat[:, 2000:2300])
ax[2].set_title('Third Split')
# Out:
# Text(0.5, 1.0, 'Third Split')

# %%
imshow(cat[0:1200,1400:1800 ])

# %%
cat.shape
# Out:
# (2500, 2392, 3)

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4), sharey=True)

ax[0].imshow(cat[:, :, 0], cmap='Reds')
ax[0].set_title('Red')

ax[1].imshow(cat[:, :, 1], cmap='Greens')
ax[1].set_title('Green')

ax[2].imshow(cat[:, :, 2], cmap='Blues')
ax[2].set_title('Blue')
# Out:
# Text(0.5, 1.0, 'Blue')

# %%
# Convert RGB image to HSV
cat_hsv = rgb2hsv(cat)

# Plot HSV channels: Hue, Saturation, and Value
fig, ax = plt.subplots(1, 3, figsize=(12, 4), sharey=True)

ax[0].imshow(cat_hsv[:, :, 0], cmap='hsv')
ax[0].set_title('Hue')

ax[1].imshow(cat_hsv[:, :, 1], cmap='gray')
ax[1].set_title('Saturation')

ax[2].imshow(cat_hsv[:, :, 2], cmap='gray')
ax[2].set_title('Value')
# Out:
# Text(0.5, 1.0, 'Value')

# %%
# Convert RGB to Grayscale
cat_gray = rgb2gray(cat)

# Plot original grayscale and binary thresholded versions
fig, ax = plt.subplots(1, 5, figsize=(17, 6), sharey=True)

ax[0].imshow(cat_gray, cmap='gray')
ax[0].set_title('Grayscale Original')

ax[1].imshow(img_as_uint(cat_gray > 0.25), cmap='gray')
ax[1].set_title('Greater than 0.25')

ax[2].imshow(img_as_uint(cat_gray > 0.50), cmap='gray')
ax[2].set_title('Greater than 0.50')

ax[3].imshow(img_as_uint(cat_gray > 0.75), cmap='gray')
ax[3].set_title('Greater than 0.75')

ax[4].imshow(img_as_uint(cat_gray > np.mean(cat_gray)), cmap='gray')
ax[4].set_title('Greater than Mean')
# Out:
# Text(0.5, 1.0, 'Greater than Mean')
